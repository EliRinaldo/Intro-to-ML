# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)

print(df.head())
# Out:
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
X1 = df.values[:,0]
X2 = df.values[:,1]
X3 = df.values[:,2]
y = df.values[:,3]

LX1 = len(X1)
LX2 = len(X2)
LX3 = len(X3)

# %%
X_0 = np.ones((LX1, 1))
X_1 = X1.reshape(LX1, 1)
X1 = np.hstack((X_0, X_1))

X_2 = X2.reshape(LX2, 1)
X2 = np.hstack((X_0, X_2))

X_3 = X3.reshape(LX3, 1)
X3 = np.hstack((X_0, X_3))

X1[:]
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616],
#        [1.        , 0.2020202 ],
#        [1.        , 0.24242424],
#        [1.        , 0.28282828],
#        [1.        , 0.32323232],
#        [1.        , 0.36363636],
#        [1.        , 0.4040404 ],
#        [1.        , 0.44444444],
#        [1.        , 0.48484848],
#        [1.        , 0.52525252],
#        [1.        , 0.56565657],
#        [1.        , 0.60606061],
#        [1.        , 0.64646465],
#        [1.        , 0.68686869],
#        [1.        , 0.72727273],
#        [1.        , 0.76767677],
#        [1.        , 0.80808081],
#        [1.        , 0.84848485],
#        [1.        , 0.88888889],
#        [1.        , 0.92929293],
#        [1.        , 0.96969697],
#        [1.        , 1.01010101],
#        [1.        , 1.05050505],
#        [1.        , 1.09090909],
# ...

# %%
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
def compute_cost(X, y, theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * LX1) * np.sum(sqrErrors)
    return J

def gradient_descent(X, y, theta, alpha, iterations):
    Ly = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha /  Ly) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
#X1
iterations = 1500
alpha = .1
theta, cost_history = gradient_descent(X1, y, theta, alpha, iterations)
print('X1:')
print('Theta=')
print(theta)
print('Cost=')
print(cost_history)
print(f'Linear model: y = {theta[0]} + {theta[1]}*X1')
# Out:
# X1:
# Theta=
# [ 5.92794892 -2.03833663]
# Cost=
# [5.16999006 4.96338989 4.7855721  ... 0.98499308 0.98499308 0.98499308]
# Linear model: y = 5.927948918061593 + -2.038336633650798*X1

# %%
#X1 Data Plot
plt.scatter(X1[:,1], y, color='purple', label='Training Data')
plt.plot(X1[:,1], X1.dot(theta), color='red', label='Linear Regression')
plt.grid(True)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
#X1 Loss Over Iteration Plot
plt.plot(range(1, iterations+1), cost_history, color='purple')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Convergence')
plt.show()

# %%
#X2
theta, cost_history = gradient_descent(X2, y, theta, alpha, iterations)
print('X2:')
print('Theta=')
print(theta)
print('Cost=')
print(cost_history)
print(f'Linear model: y = {theta[0]} + {theta[1]}*X2')
# Out:
# X2:
# Theta=
# [0.73606043 0.55760761]
# Cost=
# [7.26987578 7.00288482 6.83790041 ... 3.59936602 3.59936602 3.59936602]
# Linear model: y = 0.7360604300948078 + 0.5576076103325976*X2

# %%
#X2 Data Plot
plt.scatter(X2[:,1], y, color='lime', label='Training Data')
plt.plot(X2[:,1], X2.dot(theta), color='red', label='Linear Regression')
plt.grid(True)
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
#X2 Loss Over Iteration Plot
plt.plot(range(1, iterations+1), cost_history, color='lime')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Convergence')
plt.show()

# %%
#X3
theta, cost_history = gradient_descent(X3, y, theta, alpha, iterations)
print('X3:')
print('Theta=')
print(theta)
print('Cost=')
print(cost_history)
print(f'Linear model: y = {theta[0]} + {theta[1]}*X3')
# Out:
# X3:
# Theta=
# [ 2.8714221  -0.52048288]
# Cost=
# [4.26200819 4.21568729 4.18664662 ... 3.62945112 3.62945112 3.62945112]
# Linear model: y = 2.871422103988201 + -0.5204828843001038*X3

# %%
#X3 Data Plot
plt.scatter(X3[:,1], y, color='aqua', label='Training Data')
plt.plot(X3[:,1], X3.dot(theta), color='red', label='Linear Regression')
plt.grid(True)
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
#X3 Loss Over Iteration Plot
plt.plot(range(1, iterations+1), cost_history, color='aqua')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Convergence')
plt.show()

# %%
#Problem 2
X = np.hstack((X_0, X_1, X_2, X_3))
theta = np.zeros(4)
iterations = 1500
alpha = .1
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)

#Out of the three explanatory variables, X1 is the best fit
print('X1')
print('Theta=')
print(theta)
print('Cost=')
print(cost_history)

plt.scatter(X[:, 1], y, color='pink', label='Training Data')
plt.plot(X[:, 1], X.dot(theta), color='red', label='Linear Regression')
plt.grid(True)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# X1
# Theta=
# [ 5.31416563 -2.00371905  0.53256359 -0.26560164]
# Cost=
# [4.13064348 3.51770697 3.12758306 ... 0.73846424 0.73846424 0.73846424]

# %%
plt.plot(range(1, iterations+1), cost_history, color='pink')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Convergence')
plt.show()

# %%
#Predict the value of y for new (X1, X2, X3) values (1, 1, 1), for (2, 0, 4), and for (3, 2, 1)
NewXVal = np.array([[1, 1, 1], [2, 0, 4], [3, 2, 1]])
NewXVal = np.hstack((np.ones((NewXVal.shape[0], 1)), NewXVal))
NewYVal = NewXVal.dot(theta)
print('New Y values:')
print(NewYVal)
print("Linear Model:")
print(f" Y= {theta[0]} + {theta[1]}*X1 + {theta[2]}*X2 + {theta[3]}*X3")
# Out:
# New Y values:
# [3.57740853 0.24432097 0.10253402]
# Linear Model:
#  Y= 5.314165627499571 + -2.0037190505172755*X1 + 0.532563591425008*X2 + -0.26560163906184203*X3
